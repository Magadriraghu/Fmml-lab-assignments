# %% [markdown]
# <a href="https://colab.research.google.com/github/Magadriraghu/Fmml-lab-assignments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 12:58:13--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   212MB/s    in 0.3s
#
# 2024-03-28 12:58:13 (212 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 23032  1802.05035v1  Modeling variability in tensor decomposition m...  stat
# 19146   1304.1499v1  Unaided human decision making appears to syste...    cs
# 10087  1704.01279v1  Generative models in vision have seen rapid pr...    cs
# 16269  1611.04125v1  Joint representation learning of text and know...    cs
# 5154    1005.0437v1  Recent research on multiple kernel learning ha...  stat
# ...             ...                                                ...   ...
# 24100  1612.05601v2  Identifying and interpreting fetal standard sc...    cs
# 40254  1802.09026v1  Land-use classification based on spaceborne or...    cs
# 23211   1004.3276v1  In Image Compression, the researchers' aim is ...    cs
# 21781  1505.00428v2  Infinite Hidden Markov Models (iHMM's) are an ...  stat
# 22542  1611.00866v1  Tensor decomposition is an important technique...  stat
#
#                                                    title  year  \
# 23032  Nonnegative PARAFAC2: a flexible coupling appr...  2018
# 19146  Decision Making "Biases" and Support for Assum...  2013
# 10087  Neural Audio Synthesis of Musical Notes with W...  2017
# 16269  Joint Representation Learning of Text and Know...  2016
# 5154         A Unifying View of Multiple Kernel Learning  2010
# ...                                                  ...   ...
# 24100  SonoNet: Real-Time Detection and Localisation ...  2016
# 40254  Building Instance Classification Using Street ...  2018
# 23211  Color Image Compression Based On Wavelet Packe...  2010
# 21781  A Linear-Time Particle Gibbs Sampler for Infin...  2015
# 22542  Tensor Decomposition via Variational Auto-Encoder  2016
#
#                                                 keywords
# 23032  [variability, decomposition, challenges, separ...
# 19146  [systematically, consistency, constraints, nor...
# 10087  [generative, algorithmic, improvements, availa...
# 16269  [representation, knowledge, knowledge, complet...
# 5154   [approaches, combining, regularized, minimizat...
# ...                                                  ...
# 24100  [identifying, interpreting, ultrasound, pregna...
# 40254  [classification, spaceborne, extensively, clas...
# 23211  [compression, researchers, represent, redundan...
# 21781  [attractive, nonparametric, generalization, cl...
# 22542  [decomposition, important, technique, capturin...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 23032    [variability, decomposition, challenges, separ...
# 19146    [systematically, consistency, constraints, nor...
# 10087    [generative, algorithmic, improvements, availa...
# 16269    [representation, knowledge, knowledge, complet...
# 5154     [approaches, combining, regularized, minimizat...
#                                ...
# 30624    [foolattack, detectors, successfully, attackin...
# 34705    [comprehension, essential, component, communic...
# 10707    [regularized, minimization, dimensional, appli...
# 36952    [collaborative, initiatives, increasingly, adv...
# 36963    [representation, linearizes, remaining, deform...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8883 words.
# Out of those 4546 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a9da1bf1-44e0-424d-86f9-1834ffdcdb8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9da1bf1-44e0-424d-86f9-1834ffdcdb8c")) {                    Plotly.newPlot(                        "a9da1bf1-44e0-424d-86f9-1834ffdcdb8c",                        [{"x":["relaxation","synthetic","separation","nonnegativity","manuscript","algorithm","challenges","following","constraints","nonnegative","decomposition","variability","performance","chemometrics","variations","introduced","normative","monotonic","processes","supporting","application","consistency","reasoning","particular","assumptions","knowledge","effective","confirmation","assumption","systematically","conflicting","situations","represents","generative","improvements","realistic","synthesis","contributions","algorithmic","conditions","expressive","magnitude","qualitative","comparable","demonstrate","autoregressive","autoencoders","instruments","meaningfully","quantitative","embeddings","introduce","interpolating","autoencoder","availability","continuous","framework","accurately","baselines","including","prediction","classification","completion","significantly","relations","experiments","experiment","consistently","representation","consideration","rademacher","optimization","combining","regularized","empirically","different","criterion","criterions","formulations","complexity","approaches","regularization","strategies","generalization","analytically","algorithms","objectives","minimization","neighbors","dynamically","estimation","orthogonal","bootstrapped","technique","interpolation","experimentally","artificially","improvement","independent","techniques","parametric","generated","reduction","distribution","fundamental","classifier","discusses","preliminary","participants","treatments","information","regardless","treatment","approached","conclusion","implicitly","mainstream","proposing","integrated","cumulative","collection","statistics","researchers","theoretical","practical","applications","presented","introduces","numerical","statistical","demonstrations","discussed","introduction","increasingly","multinomial","regressions","achieving","approximate","mechanisms","scenarios","streaming","traditional","footprint","construction","significant","architectures","approximation","supervised","augmentation","unsupervised","propagates","distributed","regression","conducted","procedures","performances","combination","simulation","promising","stochastic","resampling","categorical","classical","missforest","parametrically","empirical","suggested","respectively","collected","imputation","extensive","candidate","technical","hypotheses","biological","exploration","understanding","difficulties","distributions","stability","underlying","projection","transport","estimations","parameterization","previously","adaptation","approximating","specially","integration","dermoscopic","thresholding","background","descriptors","intricate","occlusion","operations","outperforms","incorporates","recognition"],"y":[21,122,20,0,6,825,109,80,151,9,61,29,877,0,70,130,5,18,110,23,258,60,125,296,75,362,245,2,57,25,12,50,34,116,133,72,42,51,44,127,39,55,49,91,546,5,21,5,1,60,78,323,5,33,29,119,563,78,49,240,226,516,34,261,90,591,84,48,351,30,2,328,94,31,54,792,52,1,20,218,430,69,98,104,12,606,33,70,20,32,200,25,2,260,23,43,5,142,124,348,34,172,103,221,81,146,28,53,20,6,730,16,27,4,10,21,0,24,54,10,83,63,70,161,126,452,185,73,78,153,6,51,24,48,3,1,89,97,63,96,13,152,14,63,259,137,107,174,30,137,3,100,108,77,29,48,148,80,99,140,7,14,94,0,2,135,31,82,66,4,153,39,34,37,43,55,153,31,104,28,118,50,8,4,6,78,66,16,8,47,3,17,70,38,6,27,72,266,30,355],"type":"bar"},{"x":["relaxation","synthetic","separation","nonnegati ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4546,), (4546, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7991666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Mathematical</span> <span style=''>Trust</span> <span style=''>Algebra</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>International</span> <span style=''>Nation</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>Relations</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Computation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.4121037463976945);'>Evaluation</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>trust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>international</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>relations</span> <span style=''>and</span> <span style=''>its</span> <span style=''>calculus</span> <span style=''>which</span> <span style=''>related</span> <span style=''>to</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.34270650263620384);'>inference</span> <span style=''>Dempster</span> <span style=''>Shafer</span> <span style=''>theory</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.8181818181818182);'>subjective</span> <span style=''>logic</span> <span style=''>We</span> <span style=''>proposed</span> <span style=''>a</span> <span style=''>method</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>a</span> <span style=''>trust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>previously</span> <span style='background-color:rgba(0, 255, 0, 0.8181818181818182);'>subjective</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>incomputable</span> <span style=''>An</span> <span style=''>example</span> <span style=''>of</span> <span style=''>case</span> <span style=''>study</span> <span style=''>for</span> <span style=''>the</span> <span style=''>trust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>is</span> <span style=''>the</span> <span style=''>United</span> <span style=''>States</span> <span style=''>of</span> <span style=''>America</span> <span style=''>Great</span> <span style=''>Britain</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>relations</span> <span style=''>The</span> <span style=''>method</span> <span style=''>supports</span> <span style=''>decision</span> <span style=''>makers</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>government</span> <span style=''>such</span> <span style=''>as</span> <span style=''>foreign</span> <span style=''>ministry</span> <span style=''>defense</span> <span style=''>ministry</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>presidential</span> <span style=''>or</span> <span style=''>prime</span> <span style=''>minister</span> <span style=''>office</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Department</span> <span style=''>of</span> <span style=''>Defense</span> <span style=''>(DoD)</span> <span style=''>may</span> <span style=''>use</span> <span style=''>our</span> <span style=''>method</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determine</span> <span style=''>a</span> <span style=''>nation</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>known</span> <span style=''>as</span> <span style=''>a</span> <span style=''>friendly</span> <span style=''>neutral</span> <span style=''>or</span> <span style=''>hostile</span> <span style=''>nation</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Interactive</span> <span style=''>Graphics</span> <span style=''>for</span> <span style=''>Visually</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Diagnosing</span> <span style=''>Forest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classifiers</span> <span style=''>in</span> <span style=''>R</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>describes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structuring</span> <span style=''>data</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructing</span> <span style=''>plots</span> <span style=''>to</span> <span style=''>explore</span> <span style=''>forest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interactively</span> <span style=''>A</span> <span style=''>forest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>is</span> <span style=''>an</span> <span style=''>example</span> <span style=''>of</span> <span style=''>an</span> <span style=''>ensemble</span> <span style=''>produced</span> <span style=''>by</span> <span style=''>bagging</span> <span style=''>multiple</span> <span style=''>trees</span> <span style=''>The</span> <span style=''>process</span> <span style=''>of</span> <span style=''>bagging</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combining</span> <span style=''>results</span> <span style=''>from</span> <span style=''>multiple</span> <span style=''>trees</span> <span style=''>produces</span> <span style=''>numerous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diagnostics</span> <span style=''>which</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactive</span> <span style=''>graphics</span> <span style=''>can</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>lot</span> <span style=''>of</span> <span style=''>insight</span> <span style=''>into</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensions</span> <span style=''>Various</span> <span style=''>aspects</span> <span style=''>are</span> <span style=''>explored</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>to</span> <span style=''>assess</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contributions</span> <span style=''>variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>The</span> <span style=''>ideas</span> <span style=''>are</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>the</span> <span style=''>random</span> <span style=''>forest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Sobolev</span> <span style=''>GAN</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>Integral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probability</span> <span style=''>Metric</span> <span style=''>(IPM)</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3580246913580246);'>distributions</span> <span style=''>the</span> <span style=''>Sobolev</span> <span style=''>IPM</span> <span style=''>The</span> <span style=''>Sobolev</span> <span style=''>IPM</span> <span style=''>compares</span> <span style=''>the</span> <span style=''>mean</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discrepancy</span> <span style=''>of</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3580246913580246);'>distributions</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>(critic)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restricted</span> <span style=''>to</span> <span style=''>a</span> <span style=''>Sobolev</span> <span style=''>ball</span> <span style=''>defined</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>a</span> <span style=''>dominant</span> <span style=''>measure</span> <span style=''>mu</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>Sobolev</span> <span style=''>IPM</span> <span style=''>compares</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3580246913580246);'>distributions</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensions</span> <span style=''>based</span> <span style=''>on</span> <span style=''>weighted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Cumulative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Distribution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Functions</span> <span style=''>(CDF)</span> <span style=''>of</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3548387096774193);'>coordinate</span> <span style=''>on</span> <span style=''>a</span> <span style=''>leave</span> <span style=''>one</span> <span style=''>out</span> <span style=''>basis</span> <span style=''>The</span> <span style=''>Dominant</span> <span style=''>measure</span> <span style=''>mu</span> <span style=''>plays</span> <span style=''>a</span> <span style=''>crucial</span> <span style=''>role</span> <span style=''>as</span> <span style=''>it</span> <span style=''>defines</span> <span style=''>the</span> <span style=''>support</span> <span style=''>on</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>CDFs</span> <span style=''>are</span> <span style=''>compared</span> <span style=''>Sobolev</span> <span style=''>IPM</span> <span style=''>can</span> <span style=''>be</span> <span style=''>seen</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>one</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensional</span> <span style=''>Von</span> <span style=''>Mises</span> <span style=''>Cramer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistics</span> <span style=''>to</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3580246913580246);'>distributions</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>Sobolev</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Multiresolution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Imaging</span> <span style=''>With</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Application</span> <span style=''>in</span> <span style=''>Poisson</span> <span style=''>Biophotonics</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>spatially</span> <span style=''>adaptive</span> <span style=''>method</span> <span style=''>for</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>that</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>concept</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiresolution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>in</span> <span style=''>Frick</span> <span style=''>K</span> <span style=''>Marnitz</span> <span style=''>P</span> <span style=''>and</span> <span style=''>Munk</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiresolution</span> <span style=''>Dantzig</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>in</span> <span style=''>imaging</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Fundamental</span> <span style=''>concepts</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithmic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>Electron</span> <span style=''>J</span> <span style=''>Stat</span> <span style=''>6231</span> <span style=''>268</span> <span style=''>2012</span> <span style=''>It</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constitutes</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>that</span> <span style=''>uses</span> <span style=''>an</span> <span style=''>supremum</span> <span style=''>type</span> <span style=''>distance</span> <span style=''>measure</span> <span style=''>as</span> <span style=''>data</span> <span style=''>fidelity</span> <span style=''>combined</span> <span style=''>with</span> <span style=''>a</span> <span style=''>convex</span> <span style=''>cost</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approached</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>an</span> <span style=''>inexact</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>direction</span> <span style=''>method</span> <span style=''>of</span> <span style='bac ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13949339992864787)
# 	knowledge (0.12914734213342846)
# 	processing (0.10667142347484837)
# 	segmentation (0.07456296824830538)
# 	architecture (0.09240099892971816)
# 	detection (0.12557973599714592)
# 	information (0.2604352479486265)
# 	recognition (0.12665001783803068)
# 	convolutional (0.12950410274705673)
# 	different (0.2825544059935783)
#
# Some Statistics words are:
# 	stochastic (0.13920881321982975)
# 	variables (0.13820731096644967)
# 	theoretical (0.1557336004006009)
# 	statistical (0.15322984476715074)
# 	distribution (0.17776664997496244)
# 	estimation (0.17225838758137205)
# 	algorithm (0.4026039058587882)
# 	dimensional (0.18828242363545317)
# 	inference (0.19128693039559339)
# 	regression (0.17626439659489235)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cf671fa6-243b-4ffc-949d-ff1ed9522b04" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf671fa6-243b-4ffc-949d-ff1ed9522b04")) {                    Plotly.newPlot(                        "cf671fa6-243b-4ffc-949d-ff1ed9522b04",                        [{"x":["relaxation","synthetic","separation","nonnegativity","manuscript","algorithm","challenges","following","constraints","nonnegative","decomposition","variability","performance","chemometrics","variations","introduced","normative","monotonic","processes","supporting","application","consistency","reasoning","particular","assumptions","knowledge","effective","confirmation","assumption","systematically","conflicting","situations","represents","generative","improvements","realistic","synthesis","contributions","algorithmic","conditions","expressive","magnitude","qualitative","comparable","demonstrate","autoregressive","autoencoders","instruments","meaningfully","quantitative","embeddings","introduce","interpolating","autoencoder","availability","continuous","framework","accurately","baselines","including","prediction","classification","completion","significantly","relations","experiments","experiment","consistently","representation","consideration","rademacher","optimization","combining","regularized","empirically","different","criterion","criterions","formulations","complexity","approaches","regularization","strategies","generalization","analytically","algorithms","objectives","minimization","neighbors","dynamically","estimation","orthogonal","bootstrapped","technique","interpolation","experimentally","artificially","improvement","independent","techniques","parametric","generated","reduction","distribution","fundamental","classifier","discusses","preliminary","participants","treatments","information","regardless","treatment","approached","conclusion","implicitly","mainstream","proposing","integrated","cumulative","collection","statistics","researchers","theoretical","practical","applications","presented","introduces","numerical","statistical","demonstrations","discussed","introduction","increasingly","multinomial","regressions","achieving","approximate","mechanisms","scenarios","streaming","traditional","footprint","construction","significant","architectures","approximation","supervised","augmentation","unsupervised","propagates","distributed","regression","conducted","procedures","performances","combination","simulation","promising","stochastic","resampling","categorical","classical","missforest","parametrically","empirical","suggested","respectively","collected","imputation","extensive","candidate","technical","hypotheses","biological","exploration","understanding","difficulties","distributions","stability","underlying","projection","transport","estimations","parameterization","previously","adaptation","approximating","specially","integration","dermoscopic","thresholding","background","descriptors","intricate","occlusion","operations","outperforms","incorporates","recognition","detection","segmentation","boundaries","discriminative","construct","processing","evaluation","conventional","regressor","automatic","deficiencies","convolutional","interesting","challenge","arbitrary","activations","trainable","particularly","automated","composers","reproduce","sequential","characteristics","efficient","investigate","dependencies","composition","recurrent","artificial","competitive","conditional","accuracies","analogous","outperform","encompasses","advertising","successfully","inferential","additionally","contextual","developments","increased","hierarchical","generality","recommendation","inference","naturally","investigated","geometric","modification","transform","conjectured"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	nonnegativity
# 	chemometrics
# 	mainstream
# 	missforest
# 	composers
# 	inferential
# 	blackwellized
# 	justifying
# 	distributionally
# 	unregularized
# 	methylation
# 	covariates
# 	repulsion
# 	repulsive
# 	surrogates
# 	exoplanet
# 	confounders
# 	negativity
# 	fractions
# 	discourages
# Some words which never appear in Statistics papers:
# 	dermoscopic
# 	tomorrows
# 	radically
# 	deformation
# 	registrations
# 	mutations
# 	evolvable
# 	phenotypic
# 	evolvability
# 	validates
# 	manuscripts
# 	occlusions
# 	obstacles
# 	unfounded
# 	categorizing
# 	bilingual
# 	narratives
# 	preexisting
# 	conversation
# 	reflections

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.069744597249509e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7491666666666666
